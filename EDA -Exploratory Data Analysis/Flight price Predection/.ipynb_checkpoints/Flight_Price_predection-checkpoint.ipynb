# %% [markdown]
# ## Flight Price Predection(EDA + Feature Engineering)

# %%
# import Libraies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_excel('Data_Train.xlsx')
df_train.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df_test = pd.read_excel('Test_set.xlsx')
df_test
# Out:
#                 Airline Date_of_Journey    Source Destination  \
# 0           Jet Airways       6/06/2019     Delhi      Cochin
# 1                IndiGo      12/05/2019   Kolkata    Banglore
# 2           Jet Airways      21/05/2019     Delhi      Cochin
# 3     Multiple carriers      21/05/2019     Delhi      Cochin
# 4              Air Asia      24/06/2019  Banglore       Delhi
# ...                 ...             ...       ...         ...
# 2666          Air India       6/06/2019   Kolkata    Banglore
# 2667             IndiGo      27/03/2019   Kolkata    Banglore
# 2668        Jet Airways       6/03/2019     Delhi      Cochin
# 2669          Air India       6/03/2019     Delhi      Cochin
# 2670  Multiple carriers      15/06/2019     Delhi      Cochin
#
#                 Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0     DEL → BOM → COK    17:30  04:25 07 Jun  10h 55m      1 stop
# 1     CCU → MAA → BLR    06:20         10:20       4h      1 stop
# 2     DEL → BOM → COK    19:15  19:00 22 May  23h 45m      1 stop
# 3     DEL → BOM → COK    08:00         21:00      13h      1 stop
# 4           BLR → DEL    23:55  02:45 25 Jun   2h 50m    non-stop
# ...               ...      ...           ...      ...         ...
# 2666  CCU → DEL → BLR    20:30  20:25 07 Jun  23h 55m      1 stop
# 2667        CCU → BLR    14:20         16:55   2h 35m    non-stop
# 2668  DEL → BOM → COK    21:50  04:25 07 Mar   6h 35m      1 stop
# 2669  DEL → BOM → COK    04:00         19:15  15h 15m      1 stop
# 2670  DEL → BOM → COK    04:55         19:15  14h 20m      1 stop
#
#                   Additional_Info
# 0                         No info
# 1                         No info
# 2     In-flight meal not included
# 3                         No info
# 4                         No info
# ...                           ...
# 2666                      No info
# 2667                      No info
# 2668                      No info
# 2669                      No info
# 2670                      No info
#
# [2671 rows x 10 columns]

# %%
final_df = pd.concat([df_train, df_test], ignore_index = True)
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0

# %%
# read the  columns
df_columns = final_df.columns
df_columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
# read the total data set like rows and columns
final_df.shape
# Out:
# (13354, 11)

# %%
# data information
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.1+ MB

# %%
# data describe
final_df.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
final_df.tail()
# Out:
#                  Airline Date_of_Journey   Source Destination  \
# 13349          Air India       6/06/2019  Kolkata    Banglore
# 13350             IndiGo      27/03/2019  Kolkata    Banglore
# 13351        Jet Airways       6/03/2019    Delhi      Cochin
# 13352          Air India       6/03/2019    Delhi      Cochin
# 13353  Multiple carriers      15/06/2019    Delhi      Cochin
#
#                  Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 13349  CCU → DEL → BLR    20:30  20:25 07 Jun  23h 55m      1 stop
# 13350        CCU → BLR    14:20         16:55   2h 35m    non-stop
# 13351  DEL → BOM → COK    21:50  04:25 07 Mar   6h 35m      1 stop
# 13352  DEL → BOM → COK    04:00         19:15  15h 15m      1 stop
# 13353  DEL → BOM → COK    04:55         19:15  14h 20m      1 stop
#
#       Additional_Info  Price
# 13349         No info    NaN
# 13350         No info    NaN
# 13351         No info    NaN
# 13352         No info    NaN
# 13353         No info    NaN

# %%
final_df['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %% [markdown]
# # feature Engineering process

# %%
## doing the split of data_of_jounary
final_df['Date_of_Journey'].str.split('/')
# Out:
# 0        [24, 03, 2019]
# 1         [1, 05, 2019]
# 2         [9, 06, 2019]
# 3        [12, 05, 2019]
# 4        [01, 03, 2019]
#               ...
# 13349     [6, 06, 2019]
# 13350    [27, 03, 2019]
# 13351     [6, 03, 2019]
# 13352     [6, 03, 2019]
# 13353    [15, 06, 2019]
# Name: Date_of_Journey, Length: 13354, dtype: object

# %%
# we can split the data only
final_df['Date_of_Journey'].str.split('/').str[0]
# Out:
# 0        24
# 1         1
# 2         9
# 3        12
# 4        01
#          ..
# 13349     6
# 13350    27
# 13351     6
# 13352     6
# 13353    15
# Name: Date_of_Journey, Length: 13354, dtype: object

# %%
# # Now split the data of Jounary 
# final_df['Data'] = final_df['Date_of_Journey'].str.split('/').str[0]
# final_df['Month'] = final_df['Date_of_Journey'].str.split('/').str[1]
# final_df['Year'] = final_df['Date_of_Journey'].str.split('/').str[2]

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0

# %%
## apply lambda function
final_df["Date"]=final_df['Date_of_Journey'].apply(lambda x:x.split("/")[0])
final_df["Month"]=final_df['Date_of_Journey'].apply(lambda x:x.split("/")[1])
final_df["Year"]=final_df['Date_of_Journey'].apply(lambda x:x.split("/")[2])

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  Date             13354 non-null  object
#  12  Month            13354 non-null  object
#  13  Year             13354 non-null  object
# dtypes: float64(1), object(13)
# memory usage: 1.4+ MB

# %%
final_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info    Price Date  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897.0   24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662.0    1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882.0    9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218.0   12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302.0   01
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# 2    06  2019
# 3    05  2019
# 4    03  2019

# %%
# converting the data type
final_df['Date'] = final_df['Date'].astype(int)
final_df['Month'] = final_df['Month'].astype(int)
final_df['Year'] = final_df['Year'].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13354 entries, 0 to 13353
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
#  11  Date             13354 non-null  int64
#  12  Month            13354 non-null  int64
#  13  Year             13354 non-null  int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 1.4+ MB

# %%
# drop the data_of_jounery
final_df.drop('Date_of_Journey', axis = 1, inplace = True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897.0    24      3
# 1         13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2  04:25 10 Jun      19h     2 stops         No info  13882.0     9      6
# 3         23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4         21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
# let focus on the arival time 
final_df['Arrival_Time'].str.split(' ')
# Out:
# 0        [01:10, 22, Mar]
# 1                 [13:15]
# 2        [04:25, 10, Jun]
# 3                 [23:30]
# 4                 [21:35]
#                ...
# 13349    [20:25, 07, Jun]
# 13350             [16:55]
# 13351    [04:25, 07, Mar]
# 13352             [19:15]
# 13353             [19:15]
# Name: Arrival_Time, Length: 13354, dtype: object

# %%
final_df['Arrival_Time'].str.split(' ').str[0]
# Out:
# 0        01:10
# 1        13:15
# 2        04:25
# 3        23:30
# 4        21:35
#          ...
# 13349    20:25
# 13350    16:55
# 13351    04:25
# 13352    19:15
# 13353    19:15
# Name: Arrival_Time, Length: 13354, dtype: object

# %%
 # Appy lambda function
final_df['Arrival_Time'].apply(lambda x:x.split(' ')[0])
# Out:
# 0        01:10
# 1        13:15
# 2        04:25
# 3        23:30
# 4        21:35
#          ...
# 13349    20:25
# 13350    16:55
# 13351    04:25
# 13352    19:15
# 13353    19:15
# Name: Arrival_Time, Length: 13354, dtype: object

# %%
final_df['Arrival_Time'] = final_df['Arrival_Time'].apply(lambda x:x.split(' ')[0])

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m    non-stop         No info   3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2        04:25      19h     2 stops         No info  13882.0     9      6
# 3        23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4        21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
# find out the null value 
final_df.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Route                 1
# Dep_Time              0
# Arrival_Time          0
# Duration              0
# Total_Stops           1
# Additional_Info       0
# Price              2671
# Date                  0
# Month                 0
# Year                  0
# dtype: int64

# %%
# check out the duplicated values or rows
final_df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13349    False
# 13350    False
# 13351    False
# 13352    False
# 13353    False
# Length: 13354, dtype: bool

# %%
df_duplicated = final_df.duplicated().sum()
df_duplicated
# Out:
# np.int64(248)

# %%
# find out the duplicated rows columns

[features for features in final_df.columns if final_df[features].duplicated().sum() > 0]
# Out:
# ['Airline',
#  'Source',
#  'Destination',
#  'Route',
#  'Dep_Time',
#  'Arrival_Time',
#  'Duration',
#  'Total_Stops',
#  'Additional_Info',
#  'Price',
#  'Date',
#  'Month',
#  'Year']

# %%
final_df.drop_duplicates(keep=False, inplace=True)

# %%
final_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
final_df.shape
# Out:
# (12883, 13)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m    non-stop         No info   3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2        04:25      19h     2 stops         No info  13882.0     9      6
# 3        23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4        21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year
# 0  2019
# 1  2019
# 2  2019
# 3  2019
# 4  2019

# %%
# split the arrival time into time and hours
final_df['Arrival_hour'] =final_df['Arrival_Time'].apply(lambda x : x.split(':')[0])
final_df['Arrival_min'] =final_df['Arrival_Time'].apply(lambda x : x.split(':')[1])

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  Date  Month  \
# 0        01:10   2h 50m    non-stop         No info   3897.0    24      3
# 1        13:15   7h 25m     2 stops         No info   7662.0     1      5
# 2        04:25      19h     2 stops         No info  13882.0     9      6
# 3        23:30   5h 25m      1 stop         No info   6218.0    12      5
# 4        21:35   4h 45m      1 stop         No info  13302.0     1      3
#
#    Year Arrival_hour Arrival_min
# 0  2019           01          10
# 1  2019           13          15
# 2  2019           04          25
# 3  2019           23          30
# 4  2019           21          35

# %%
final_df['Arrival_hour'] = final_df['Arrival_hour'].astype(int)
final_df['Arrival_min'] = final_df['Arrival_min'].astype(int)

# %%
 final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12883 entries, 0 to 13353
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          12883 non-null  object
#  1   Source           12883 non-null  object
#  2   Destination      12883 non-null  object
#  3   Route            12882 non-null  object
#  4   Dep_Time         12883 non-null  object
#  5   Arrival_Time     12883 non-null  object
#  6   Duration         12883 non-null  object
#  7   Total_Stops      12882 non-null  object
#  8   Additional_Info  12883 non-null  object
#  9   Price            10264 non-null  float64
#  10  Date             12883 non-null  int64
#  11  Month            12883 non-null  int64
#  12  Year             12883 non-null  int64
#  13  Arrival_hour     12883 non-null  int64
#  14  Arrival_min      12883 non-null  int64
# dtypes: float64(1), int64(5), object(9)
# memory usage: 1.6+ MB

# %%
# final drop the arival time columns
final_df.drop('Arrival_Time', axis =1 ,inplace =True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#   Total_Stops Additional_Info    Price  Date  Month  Year  Arrival_hour  \
# 0    non-stop         No info   3897.0    24      3  2019             1
# 1     2 stops         No info   7662.0     1      5  2019            13
# 2     2 stops         No info  13882.0     9      6  2019             4
# 3      1 stop         No info   6218.0    12      5  2019            23
# 4      1 stop         No info  13302.0     1      3  2019            21
#
#    Arrival_min
# 0           10
# 1           15
# 2           25
# 3           30
# 4           35

# %%
# know focus on Dep_Time
final_df['Dep_Hour'] = final_df['Dep_Time'].apply(lambda x : x.split(':')[0])
final_df['Dep_Min'] = final_df['Dep_Time'].apply(lambda x : x.split(':')[1])

# %%
final_df['Dep_Hour'] =final_df['Dep_Hour'].astype(int)
final_df['Dep_Min'] = final_df['Dep_Min'].astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12883 entries, 0 to 13353
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          12883 non-null  object
#  1   Source           12883 non-null  object
#  2   Destination      12883 non-null  object
#  3   Route            12882 non-null  object
#  4   Dep_Time         12883 non-null  object
#  5   Duration         12883 non-null  object
#  6   Total_Stops      12882 non-null  object
#  7   Additional_Info  12883 non-null  object
#  8   Price            10264 non-null  float64
#  9   Date             12883 non-null  int64
#  10  Month            12883 non-null  int64
#  11  Year             12883 non-null  int64
#  12  Arrival_hour     12883 non-null  int64
#  13  Arrival_min      12883 non-null  int64
#  14  Dep_Hour         12883 non-null  int64
#  15  Dep_Min          12883 non-null  int64
# dtypes: float64(1), int64(7), object(8)
# memory usage: 1.7+ MB

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#   Total_Stops Additional_Info    Price  Date  Month  Year  Arrival_hour  \
# 0    non-stop         No info   3897.0    24      3  2019             1
# 1     2 stops         No info   7662.0     1      5  2019            13
# 2     2 stops         No info  13882.0     9      6  2019             4
# 3      1 stop         No info   6218.0    12      5  2019            23
# 4      1 stop         No info  13302.0     1      3  2019            21
#
#    Arrival_min  Dep_Hour  Dep_Min
# 0           10        22       20
# 1           15         5       50
# 2           25         9       25
# 3           30        18        5
# 4           35        16       50

# %%
final_df.drop('Dep_Time',axis = 1, inplace =True)

# %%
final_df.head(1)
# Out:
#   Airline    Source Destination      Route Duration Total_Stops  \
# 0  IndiGo  Banglore   New Delhi  BLR → DEL   2h 50m    non-stop
#
#   Additional_Info   Price  Date  Month  Year  Arrival_hour  Arrival_min  \
# 0         No info  3897.0    24      3  2019             1           10
#
#    Dep_Hour  Dep_Min
# 0        22       20

# %%
 final_df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
final_df['Total_Stops'].isnull().sum()
# Out:
# np.int64(1)

# %%
# # check out which data is nan value
# final_df[final_df['Total_Stops'].isnull()]

# %%
final_df['Total_Stops'].fillna('1 stop', inplace=True)
# Out:
# C:\Users\ravik\AppData\Local\Temp\ipykernel_4320\3989858047.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   final_df['Total_Stops'].fillna('1 stop', inplace=True)

# %%
final_df['Total_Stops'].isnull().sum()
# Out:
# np.int64(0)

# %%
# from sklearn.preprocessing import LabelEncoder
# label_object =LabelEncoder() 
# final_df['Total_Stops'] = label_object.fit_transform(final_df['Total_Stops'])
# final_df.head()

# %%
final_df['Total_Stops'] = final_df['Total_Stops'].map({'non-stop': 0, '2 stops':1, '1 stop':2, '3 stops':3, '4 stops':4})

# %%
final_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#    Total_Stops Additional_Info    Price  Date  Month  Year  Arrival_hour  \
# 0            0         No info   3897.0    24      3  2019             1
# 1            1         No info   7662.0     1      5  2019            13
# 2            1         No info  13882.0     9      6  2019             4
# 3            2         No info   6218.0    12      5  2019            23
# 4            2         No info  13302.0     1      3  2019            21
#
#    Arrival_min  Dep_Hour  Dep_Min
# 0           10        22       20
# 1           15         5       50
# 2           25         9       25
# 3           30        18        5
# 4           35        16       50

# %%
# now we can drop route columns
final_df.drop('Route', axis =1 , inplace = True)

# %%
final_df.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m            0         No info
# 1    Air India   Kolkata    Banglore   7h 25m            1         No info
# 2  Jet Airways     Delhi      Cochin      19h            1         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m            2         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m            2         No info
#
#      Price  Date  Month  Year  Arrival_hour  Arrival_min  Dep_Hour  Dep_Min
# 0   3897.0    24      3  2019             1           10        22       20
# 1   7662.0     1      5  2019            13           15         5       50
# 2  13882.0     9      6  2019             4           25         9       25
# 3   6218.0    12      5  2019            23           30        18        5
# 4  13302.0     1      3  2019            21           35        16       50

# %%
final_df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12883 entries, 0 to 13353
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          12883 non-null  object
#  1   Source           12883 non-null  object
#  2   Destination      12883 non-null  object
#  3   Duration         12883 non-null  object
#  4   Total_Stops      12883 non-null  int64
#  5   Additional_Info  12883 non-null  object
#  6   Price            10264 non-null  float64
#  7   Date             12883 non-null  int64
#  8   Month            12883 non-null  int64
#  9   Year             12883 non-null  int64
#  10  Arrival_hour     12883 non-null  int64
#  11  Arrival_min      12883 non-null  int64
#  12  Dep_Hour         12883 non-null  int64
#  13  Dep_Min          12883 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# memory usage: 1.5+ MB

# %%
# convert the duration form hours to minutes
final_df['Duration'].str.split(' ').str[0]
# Out:
# 0         2h
# 1         7h
# 2        19h
# 3         5h
# 4         4h
#         ...
# 13349    23h
# 13350     2h
# 13351     6h
# 13352    15h
# 13353    14h
# Name: Duration, Length: 12883, dtype: object

# %%
type(final_df['Duration'].str.split(' ').str[0])
# Out:
# pandas.core.series.Series

# %%
final_df['Duration'].str.split(' ').str[0].str.split('h')
# Out:
# 0         [2, ]
# 1         [7, ]
# 2        [19, ]
# 3         [5, ]
# 4         [4, ]
#           ...
# 13349    [23, ]
# 13350     [2, ]
# 13351     [6, ]
# 13352    [15, ]
# 13353    [14, ]
# Name: Duration, Length: 12883, dtype: object

# %%
final_df['Duration'].str.split(' ').str[0].str.split('h').str[0]
# Out:
# 0         2
# 1         7
# 2        19
# 3         5
# 4         4
#          ..
# 13349    23
# 13350     2
# 13351     6
# 13352    15
# 13353    14
# Name: Duration, Length: 12883, dtype: object

# %%
final_df['Duration_hours'] = final_df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
final_df.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m            0         No info
# 1    Air India   Kolkata    Banglore   7h 25m            1         No info
# 2  Jet Airways     Delhi      Cochin      19h            1         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m            2         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m            2         No info
#
#      Price  Date  Month  Year  Arrival_hour  Arrival_min  Dep_Hour  Dep_Min  \
# 0   3897.0    24      3  2019             1           10        22       20
# 1   7662.0     1      5  2019            13           15         5       50
# 2  13882.0     9      6  2019             4           25         9       25
# 3   6218.0    12      5  2019            23           30        18        5
# 4  13302.0     1      3  2019            21           35        16       50
#
#   Duration_hours
# 0              2
# 1              7
# 2             19
# 3              5
# 4              4

# %%
final_df[final_df['Duration'] == '5m']
# Out:
#          Airline  Source Destination Duration  Total_Stops Additional_Info  \
# 6474   Air India  Mumbai   Hyderabad       5m            1         No info
# 13343  Air India  Mumbai   Hyderabad       5m            1         No info
#
#          Price  Date  Month  Year  Arrival_hour  Arrival_min  Dep_Hour  \
# 6474   17327.0     6      3  2019            16           55        16
# 13343      NaN    12      3  2019            16           55        16
#
#        Dep_Min Duration_hours
# 6474        50             5m
# 13343       50             5m

# %%
# probably to drop the above two rows
final_df.drop(6474, axis =0, inplace = True)
final_df.drop(13343, axis = 0, inplace =True)
final_df.reset_index(drop=True, inplace=True)

# %%
final_df['Duration_hours'] = final_df['Duration_hours'].astype(int)

# %%
final_df[final_df['Duration'] == '5m']
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Duration, Total_Stops, Additional_Info, Price, Date, Month, Year, Arrival_hour, Arrival_min, Dep_Hour, Dep_Min, Duration_hours]
# Index: []

# %%
#checkout any missing value
final_df[final_df['Duration'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Duration, Total_Stops, Additional_Info, Price, Date, Month, Year, Arrival_hour, Arrival_min, Dep_Hour, Dep_Min, Duration_hours]
# Index: []

# %%
final_df['Duration'].str.split(' ').str[1]
# Out:
# 0        50m
# 1        25m
# 2        NaN
# 3        25m
# 4        45m
#         ...
# 12876    55m
# 12877    35m
# 12878    35m
# 12879    15m
# 12880    20m
# Name: Duration, Length: 12881, dtype: object

# %%
final_df['Duration_Min'] = final_df['Duration'].str.split(' ').str[1]

# %%
final_df['Duration_Min'] = final_df['Duration'].str.split(' ').str[1].str.split('m')

# %%
final_df.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m            0         No info
# 1    Air India   Kolkata    Banglore   7h 25m            1         No info
# 2  Jet Airways     Delhi      Cochin      19h            1         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m            2         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m            2         No info
#
#      Price  Date  Month  Year  Arrival_hour  Arrival_min  Dep_Hour  Dep_Min  \
# 0   3897.0    24      3  2019             1           10        22       20
# 1   7662.0     1      5  2019            13           15         5       50
# 2  13882.0     9      6  2019             4           25         9       25
# 3   6218.0    12      5  2019            23           30        18        5
# 4  13302.0     1      3  2019            21           35        16       50
#
#    Duration_hours Duration_Min
# 0               2       [50, ]
# 1               7       [25, ]
# 2              19          NaN
# 3               5       [25, ]
# 4               4       [45, ]

# %%
final_df['Duration_Min'] = final_df['Duration'].str.split(' ').str[1].str.split(',')

# %%
final_df.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m            0         No info
# 1    Air India   Kolkata    Banglore   7h 25m            1         No info
# 2  Jet Airways     Delhi      Cochin      19h            1         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m            2         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m            2         No info
#
#      Price  Date  Month  Year  Arrival_hour  Arrival_min  Dep_Hour  Dep_Min  \
# 0   3897.0    24      3  2019             1           10        22       20
# 1   7662.0     1      5  2019            13           15         5       50
# 2  13882.0     9      6  2019             4           25         9       25
# 3   6218.0    12      5  2019            23           30        18        5
# 4  13302.0     1      3  2019            21           35        16       50
#
#    Duration_hours Duration_Min
# 0               2        [50m]
# 1               7        [25m]
# 2              19          NaN
# 3               5        [25m]
# 4               4        [45m]

# %%
final_df['Duration_Min'] = final_df['Duration'].str.split(' ').str[1].str.split('m').str[0]

# %%
final_df.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m            0         No info
# 1    Air India   Kolkata    Banglore   7h 25m            1         No info
# 2  Jet Airways     Delhi      Cochin      19h            1         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m            2         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m            2         No info
#
#      Price  Date  Month  Year  Arrival_hour  Arrival_min  Dep_Hour  Dep_Min  \
# 0   3897.0    24      3  2019             1           10        22       20
# 1   7662.0     1      5  2019            13           15         5       50
# 2  13882.0     9      6  2019             4           25         9       25
# 3   6218.0    12      5  2019            23           30        18        5
# 4  13302.0     1      3  2019            21           35        16       50
#
#    Duration_hours Duration_Min
# 0               2           50
# 1               7           25
# 2              19          NaN
# 3               5           25
# 4               4           45

# %%
final_df['Duration_Min'].isnull().sum()
# Out:
# np.int64(1229)

# %%
final_df['Duration_Min'].fillna(0, inplace = True)
# Out:
# C:\Users\ravik\AppData\Local\Temp\ipykernel_4320\1665332558.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   final_df['Duration_Min'].fillna(0, inplace = True)

# %%
final_df['Duration_Min'].isnull().sum()
# Out:
# np.int64(0)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12881 entries, 0 to 12880
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          12881 non-null  object
#  1   Source           12881 non-null  object
#  2   Destination      12881 non-null  object
#  3   Duration         12881 non-null  object
#  4   Total_Stops      12881 non-null  int64
#  5   Additional_Info  12881 non-null  object
#  6   Price            10263 non-null  float64
#  7   Date             12881 non-null  int64
#  8   Month            12881 non-null  int64
#  9   Year             12881 non-null  int64
#  10  Arrival_hour     12881 non-null  int64
#  11  Arrival_min      12881 non-null  int64
#  12  Dep_Hour         12881 non-null  int64
#  13  Dep_Min          12881 non-null  int64
#  14  Duration_hours   12881 non-null  int64
#  15  Duration_Min     12881 non-null  object
# dtypes: float64(1), int64(9), object(6)
# memory usage: 1.6+ MB

# %%
final_df['Duration_Min'] = final_df['Duration_Min'].astype(int)

# %%
final_df.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m            0         No info
# 1    Air India   Kolkata    Banglore   7h 25m            1         No info
# 2  Jet Airways     Delhi      Cochin      19h            1         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m            2         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m            2         No info
#
#      Price  Date  Month  Year  Arrival_hour  Arrival_min  Dep_Hour  Dep_Min  \
# 0   3897.0    24      3  2019             1           10        22       20
# 1   7662.0     1      5  2019            13           15         5       50
# 2  13882.0     9      6  2019             4           25         9       25
# 3   6218.0    12      5  2019            23           30        18        5
# 4  13302.0     1      3  2019            21           35        16       50
#
#    Duration_hours  Duration_Min
# 0               2            50
# 1               7            25
# 2              19             0
# 3               5            25
# 4               4            45

# %%
# now drop the duration column
final_df.drop('Duration', axis =1, inplace =True)

# %%
final_df.head(1)
# Out:
#   Airline    Source Destination  Total_Stops Additional_Info   Price  Date  \
# 0  IndiGo  Banglore   New Delhi            0         No info  3897.0    24
#
#    Month  Year  Arrival_hour  Arrival_min  Dep_Hour  Dep_Min  Duration_hours  \
# 0      3  2019             1           10        22       20               2
#
#    Duration_Min
# 0            50

# %%
final_df['Source'].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
final_df['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
label_object =LabelEncoder()
final_df['Airline'] = label_object.fit_transform(final_df['Airline'])
final_df['Source'] = label_object.fit_transform(final_df['Source'])
final_df['Additional_Info'] = label_object.fit_transform(final_df['Additional_Info'])
final_df['Destination'] = label_object.fit_transform(final_df['Destination'])

# %%
final_df.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info    Price  Date  \
# 0        3       0            5            0                8   3897.0    24
# 1        1       3            0            1                8   7662.0     1
# 2        4       2            1            1                8  13882.0     9
# 3        3       3            0            2                8   6218.0    12
# 4        3       0            5            2                8  13302.0     1
#
#    Month  Year  Arrival_hour  Arrival_min  Dep_Hour  Dep_Min  Duration_hours  \
# 0      3  2019             1           10        22       20               2
# 1      5  2019            13           15         5       50               7
# 2      6  2019             4           25         9       25              19
# 3      5  2019            23           30        18        5               5
# 4      3  2019            21           35        16       50               4
#
#    Duration_Min
# 0            50
# 1            25
# 2             0
# 3            25
# 4            45

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12881 entries, 0 to 12880
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          12881 non-null  int64
#  1   Source           12881 non-null  int64
#  2   Destination      12881 non-null  int64
#  3   Total_Stops      12881 non-null  int64
#  4   Additional_Info  12881 non-null  int64
#  5   Price            10263 non-null  float64
#  6   Date             12881 non-null  int64
#  7   Month            12881 non-null  int64
#  8   Year             12881 non-null  int64
#  9   Arrival_hour     12881 non-null  int64
#  10  Arrival_min      12881 non-null  int64
#  11  Dep_Hour         12881 non-null  int64
#  12  Dep_Min          12881 non-null  int64
#  13  Duration_hours   12881 non-null  int64
#  14  Duration_Min     12881 non-null  int64
# dtypes: float64(1), int64(14)
# memory usage: 1.5 MB

# %%
# this is also converting categorical data into numerical data
# from sklearn.preprocessing import OneHotEncoder 
# ohe =OneHotEncoder()
# final_df['Airline'] = ohe.fit_transform(final_df['Airline'])

# %%
pd.get_dummies(final_df, columns = ['Airline', 'Source', 'Destination','Additional_Info'], drop_first= True)
# Out:
#        Total_Stops    Price  Date  Month  Year  Arrival_hour  Arrival_min  \
# 0                0   3897.0    24      3  2019             1           10
# 1                1   7662.0     1      5  2019            13           15
# 2                1  13882.0     9      6  2019             4           25
# 3                2   6218.0    12      5  2019            23           30
# 4                2  13302.0     1      3  2019            21           35
# ...            ...      ...   ...    ...   ...           ...          ...
# 12876            2      NaN     6      6  2019            20           25
# 12877            0      NaN    27      3  2019            16           55
# 12878            2      NaN     6      3  2019             4           25
# 12879            2      NaN     6      3  2019            19           15
# 12880            2      NaN    15      6  2019            19           15
#
#        Dep_Hour  Dep_Min  Duration_hours  ...  Destination_5  \
# 0            22       20               2  ...           True
# 1             5       50               7  ...          False
# 2             9       25              19  ...          False
# 3            18        5               5  ...          False
# 4            16       50               4  ...           True
# ...         ...      ...             ...  ...            ...
# 12876        20       30              23  ...          False
# 12877        14       20               2  ...          False
# 12878        21       50               6  ...          False
# 12879         4        0              15  ...          False
# 12880         4       55              14  ...          False
#
#        Additional_Info_1  Additional_Info_2  Additional_Info_3  \
# 0                  False              False              False
# 1                  False              False              False
# 2                  False              False              False
# 3                  False              False              False
# 4                  False              False              False
# ...                  ...                ...                ...
# 12876              False              False              False
# 12877              False              False              False
# 12878              False              False              False
# 12879              False              False              False
# 12880              False              False              False
#
#        Additional_Info_4  Additional_Info_5  Additional_Info_6  \
# 0                  False              False              False
# 1                  False              False              False
# 2                  False              False              False
# 3                  False              False              False
# 4                  False              False              False
# ...                  ...                ...                ...
# 12876              False              False              False
# 12877              False              False              False
# 12878              False              False              False
# 12879              False              False              False
# 12880              False              False              False
#
#        Additional_Info_7  Additional_Info_8  Additional_Info_9
# 0                  False               True              False
# 1                  False               True              False
# 2                  False               True              False
# 3                  False               True              False
# 4                  False               True              False
# ...                  ...                ...                ...
# 12876              False               True              False
# 12877              False               True              False
# 12878              False               True              False
# 12879              False               True              False
# 12880              False               True              False
#
# [12881 rows x 40 columns]

# %%
final_df.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info    Price  Date  \
# 0        3       0            5            0                8   3897.0    24
# 1        1       3            0            1                8   7662.0     1
# 2        4       2            1            1                8  13882.0     9
# 3        3       3            0            2                8   6218.0    12
# 4        3       0            5            2                8  13302.0     1
#
#    Month  Year  Arrival_hour  Arrival_min  Dep_Hour  Dep_Min  Duration_hours  \
# 0      3  2019             1           10        22       20               2
# 1      5  2019            13           15         5       50               7
# 2      6  2019             4           25         9       25              19
# 3      5  2019            23           30        18        5               5
# 4      3  2019            21           35        16       50               4
#
#    Duration_Min
# 0            50
# 1            25
# 2             0
# 3            25
# 4            45

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Check missing values
print("Missing values in Price column:", final_df['Price'].isnull().sum())

# Plot distribution
plt.figure(figsize=(8, 5))
sns.histplot(final_df['Price'], bins=30, kde=True, color='skyblue', edgecolor='black')
plt.title('Distribution of Price Column', fontsize=16)
plt.xlabel('Price', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(True)
plt.show()
# Out:
# Missing values in Price column: 2618

# %%
from sklearn.impute import SimpleImputer

# Use median strategy for right-skewed numeric data
medianImputer = SimpleImputer(strategy='median')
final_df['Price'] = medianImputer.fit_transform(final_df[['Price']])
final_df.tail()
# Out:
#        Airline  Source  Destination  Total_Stops  Additional_Info   Price  \
# 12876        1       3            0            2                8  8073.0
# 12877        3       3            0            0                8  8073.0
# 12878        4       2            1            2                8  8073.0
# 12879        1       2            1            2                8  8073.0
# 12880        6       2            1            2                8  8073.0
#
#        Date  Month  Year  Arrival_hour  Arrival_min  Dep_Hour  Dep_Min  \
# 12876     6      6  2019            20           25        20       30
# 12877    27      3  2019            16           55        14       20
# 12878     6      3  2019             4           25        21       50
# 12879     6      3  2019            19           15         4        0
# 12880    15      6  2019            19           15         4       55
#
#        Duration_hours  Duration_Min
# 12876              23            55
# 12877               2            35
# 12878               6            35
# 12879              15            15
# 12880              14            20

# %%
print('Missing value in price columns', final_df['Price'].isnull().sum())
# Out:
# Missing value in price columns 0

# %%
# let set feature and target data set

x = final_df.drop('Price', axis =1)
y =final_df['Price']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size =0.2, random_state = 42)

# %%
# let train the model 
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score
y_pred = model.predict(x_test)
print("R2 Score:", r2_score(y_test, y_pred))
print("RMSE:", mean_squared_error(y_test, y_pred))
# Out:
# R2 Score: 0.32076571990266434
# RMSE: 11596156.252056073

# %%
## Observation poor accarcy try another model
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators = 100, random_state =42)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = model.predict(x_test)
print("R2 Score:", r2_score(y_test, y_pred))
print("RMSE:", mean_squared_error(y_test, y_pred))
# Out:
# R2 Score: 0.5813809344278926
# RMSE: 7146830.242089993

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators = 100, random_state =42)
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(x_test)
print("R2 Score:", r2_score(y_test, y_pred))
print("RMSE:", mean_squared_error(y_test, y_pred))
# Out:
# R2 Score: 0.29785818983907997
# RMSE: 11987242.664726427

# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in d:\data science\uptor\.venv\lib\site-packages (4.6.0)
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy>=1.17.0 in d:\data science\uptor\.venv\lib\site-packages (from lightgbm) (2.2.2)
# Requirement already satisfied: scipy in d:\data science\uptor\.venv\lib\site-packages (from lightgbm) (1.15.1)

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in d:\data science\uptor\.venv\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy in d:\data science\uptor\.venv\lib\site-packages (from xgboost) (2.2.2)
# Requirement already satisfied: scipy in d:\data science\uptor\.venv\lib\site-packages (from xgboost) (1.15.1)
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.ensemble import GradientBoostingRegressor

model = GradientBoostingRegressor(random_state=42)
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

print("R2 Score:", r2_score(y_test, y_pred))
print("RMSE:", mean_squared_error(y_test, y_pred))
# Out:
# R2 Score: 0.6228802024095861
# RMSE: 6438338.327057816
